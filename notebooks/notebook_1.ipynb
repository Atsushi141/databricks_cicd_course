# %%
from databricks.connect import DatabricksSession

# %% [markdown]
# .databrickscfgファイルに設定がない場合

# %%
spark = DatabricksSession.builder.serverless().profile("DEFAULT").getOrCreate()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1770349770.492673 15346183 fork_posix.cc:71] Other threads are currently calling into gRPC, skipping fork() handlers

# %% [markdown]
# .databrickscfgにserverless_compute_id = autoを設定している場合

# %%
spark = DatabricksSession.builder.getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 spark = DatabricksSession.builder.getOrCreate()
#
# NameError: name 'DatabricksSession' is not defined

# %%
spark.sql("SELECT 1")
# Out:
# I0000 00:00:1770349856.808196 15346183 fork_posix.cc:71] Other threads are currently calling into gRPC, skipping fork() handlers
# DataFrame[1: int]

# %%
df = spark.read.csv("/Volumes/yfinance-dev/raw/raw/data_j.csv")

# %%
df.show()
# Out:
# I0000 00:00:1770349903.613848 15346183 fork_posix.cc:71] Other threads are currently calling into gRPC, skipping fork() handlers
# +--------+------+--------------------------------------+--------------------+------------+------------+------------+------------------------+----------+-------------+
# |     _c0|   _c1|                                   _c2|                 _c3|         _c4|         _c5|         _c6|                     _c7|       _c8|          _c9|
# +--------+------+--------------------------------------+--------------------+------------+------------+------------+------------------------+----------+-------------+
# |    日付|コード|                                銘柄名|      市場・商品区分|33業種コード|  33業種区分|17業種コード|              17業種区分|規模コード|     規模区分|
# |20260131|  1301|                                  極洋|プライム（内国株式）|          50|水産・農林業|           1|                    食品|         6|TOPIX Small 1|
# |20260131|  1305| ｉＦｒｅｅＥＴＦ　ＴＯＰＩＸ（年１...|            ETF・ETN|           -|           -|           -|                       -|         -|            -|
# |20260131|  1306| ＮＥＸＴ　ＦＵＮＤＳ　ＴＯＰＩＸ連...|            ETF・ETN|           -|           -|           -|                       -|         -|            -|
# |20260131|  1308|    上場インデックスファンドＴＯＰＩＸ|            ETF・ETN|           -|           -|           -|                       -|         -|            -|
# |20260131|  1309| ＮＥＸＴ　ＦＵＮＤＳ　ＣｈｉｎａＡ...|            ETF・ETN|           -|           -|           -|                       -|         -|            -|
# |20260131|  130A|    Ｖｅｒｉｔａｓ　Ｉｎ　Ｓｉｌｉｃｏ|グロース（内国株式）|        3250|      医薬品|           5|                  医薬品|         -|            -|
# |20260131|  1311| ＮＥＸＴ　ＦＵＮＤＳ　ＴＯＰＩＸ　...|            ETF・ETN|           -|           -|           -|                       -|         -|            -|
# |20260131|  1319| ＮＥＸＴ　ＦＵＮＤＳ　日経３００株...|            ETF・ETN|           -|           -|           -|                       -|         -|            -|
# |20260131|  131A|                        ＣＣＮグループ|          PRO Market|        5250|情報・通信業|          10|情報通信・サービスその他|         -|            -|
# |20260131|  1320| ｉＦｒｅｅＥＴＦ　日経２２５（年１...|            ETF・ETN|           -|           -|           -|                       -|         -|            -|
# |20260131|  1321| ＮＥＸＴ　ＦＵＮＤＳ　日経２２５連...|            ETF・ETN|           -|           -|           -|                       -|         -|            -|
# |20260131|  1322| 上場インデックスファンド中国Ａ株（...|            ETF・ETN|           -|           -|           -|                       -|         -|            -|
# |20260131|  1325| ＮＥＸＴ　ＦＵＮＤＳ　ブラジル株式...|            ETF・ETN|           -|           -|           -|                       -|         -|            -|
# |20260131|  1326|              ＳＰＤＲゴールド・シェア|            ETF・ETN|           -|           -|           -|                       -|         -|            -|
# |20260131|  1328| ＮＥＸＴ　ＦＵＮＤＳ　金価格連動型...|            ETF・ETN|           -|           -|           -|                       -|         -|            -|
# |20260131|  1329|ｉシェアーズ・コア　日経２２５　ＥＴＦ|            ETF・ETN|           -|           -|           -|                       -|         -|            -|
# |20260131|  132A|              アイエヌホールディングス|          PRO Market|        5050|      陸運業|          12|              運輸・物流|         -|            -|
# |20260131|  1330|        上場インデックスファンド２２５|            ETF・ETN|           -|           -|           -|                       -|         -|            -|
# |20260131|  1332|                              ニッスイ|プライム（内国株式）|          50|水産・農林業|           1|                    食品|         4| TOPIX Mid400|
# +--------+------+--------------------------------------+--------------------+------------+------------+------------+------------------------+----------+-------------+
# only showing top 20 rows

# %%
print("This is a notebook")
# Out:
# This is a notebook

# %%
spark.sql("select 1")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1770104357.406785 13663589 fork_posix.cc:71] Other threads are currently calling into gRPC, skipping fork() handlers
# I0000 00:00:1770104360.595540 13663589 fork_posix.cc:71] Other threads are currently calling into gRPC, skipping fork() handlers
# DataFrame[1: int]
